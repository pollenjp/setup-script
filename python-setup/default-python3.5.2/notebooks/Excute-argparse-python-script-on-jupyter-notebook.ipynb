# %% [markdown]
# # Excute-argparse-python-script-on-jupyter-notebook
#
# ## Chainer test
#
# - [chainer/examples/mnist/train_mnist.py](https://github.com/chainer/chainer/blob/master/examples/mnist/train_mnist.py)

# %%
#!/usr/bin/env python
import argparse

import chainer
import chainer.functions as F
import chainer.links as L
from chainer import training
from chainer.training import extensions


# Network definition
class MLP(chainer.Chain):

    def __init__(self, n_units, n_out):
        super(MLP, self).__init__()
        with self.init_scope():
            # the size of the inputs to each layer will be inferred
            self.l1 = L.Linear(None, n_units)  # n_in -> n_units
            self.l2 = L.Linear(None, n_units)  # n_units -> n_units
            self.l3 = L.Linear(None, n_out)  # n_units -> n_out

    def forward(self, x):
        h1 = F.relu(self.l1(x))
        h2 = F.relu(self.l2(h1))
        return self.l3(h2)


def main():
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', type=int, default=100,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=20,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=-1,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default='result',
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default='',
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', type=int, default=1000,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()

    print('GPU: {}'.format(args.gpu))
    print('# unit: {}'.format(args.unit))
    print('# Minibatch-size: {}'.format(args.batchsize))
    print('# epoch: {}'.format(args.epoch))
    print('')

    # Set up a neural network to train
    # Classifier reports softmax cross entropy loss and accuracy at every
    # iteration, which will be used by the PrintReport extension below.
    model = L.Classifier(MLP(args.unit, 10))
    if args.gpu >= 0:
        # Make a specified GPU current
        chainer.backends.cuda.get_device_from_id(args.gpu).use()
        model.to_gpu()  # Copy the model to the GPU

    # Setup an optimizer
    optimizer = chainer.optimizers.Adam()
    optimizer.setup(model)

    # Load the MNIST dataset
    train, test = chainer.datasets.get_mnist()

    train_iter = chainer.iterators.SerialIterator(train, args.batchsize)
    test_iter = chainer.iterators.SerialIterator(test, args.batchsize,
                                                 repeat=False, shuffle=False)

    # Set up a trainer
    updater = training.updaters.StandardUpdater(
        train_iter, optimizer, device=args.gpu)
    trainer = training.Trainer(updater, (args.epoch, 'epoch'), out=args.out)

    # Evaluate the model with the test dataset for each epoch
    trainer.extend(extensions.Evaluator(test_iter, model, device=args.gpu))

    # Dump a computational graph from 'loss' variable at the first iteration
    # The "main" refers to the target link of the "main" optimizer.
    trainer.extend(extensions.dump_graph('main/loss'))

    # Take a snapshot for each specified epoch
    frequency = args.epoch if args.frequency == -1 else max(1, args.frequency)
    trainer.extend(extensions.snapshot(), trigger=(frequency, 'epoch'))

    # Write a log of evaluation statistics for each epoch
    trainer.extend(extensions.LogReport())

    # Save two plot images to the result dir
    if args.plot and extensions.PlotReport.available():
        trainer.extend(
            extensions.PlotReport(['main/loss', 'validation/main/loss'],
                                  'epoch', file_name='loss.png'))
        trainer.extend(
            extensions.PlotReport(
                ['main/accuracy', 'validation/main/accuracy'],
                'epoch', file_name='accuracy.png'))

    # Print selected entries of the log to stdout
    # Here "main" refers to the target link of the "main" optimizer again, and
    # "validation" refers to the default name of the Evaluator extension.
    # Entries other than 'epoch' are reported by the Classifier link, called by
    # either the updater or the evaluator.
    trainer.extend(extensions.PrintReport(
        ['epoch', 'main/loss', 'validation/main/loss',
         'main/accuracy', 'validation/main/accuracy', 'elapsed_time']))

    # Print a progress bar to stdout
    trainer.extend(extensions.ProgressBar())

    if args.resume:
        # Resume from a snapshot
        chainer.serializers.load_npz(args.resume, trainer)

    # Run the training
    trainer.run()

# %%
# https://stackoverflow.com/a/30662356

if __name__ == "__main__":
    import sys
    sys.argv = ['-f'] + ["--gpu", "1"]
    main()
# Out:
# GPU: 1
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
# Downloading from http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz...
# Downloading from http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz...
# Downloading from http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz...
# Downloading from http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz...
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     258.25 iters/sec. Estimated time to finish: 0:00:45.692877.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     258.08 iters/sec. Estimated time to finish: 0:00:45.334674.
#      total [#.................................................]  3.33%
# this epoch [#################################.................] 66.67%
#        400 iter, 0 epoch / 20 epochs
#     258.38 iters/sec. Estimated time to finish: 0:00:44.894434.
#      total [##................................................]  4.17%
# this epoch [#########################################.........] 83.33%
#        500 iter, 0 epoch / 20 epochs
#      258.8 iters/sec. Estimated time to finish: 0:00:44.435052.
# 1           0.192274    0.0966552             0.941834       0.9683                    10.5345
#      total [##................................................]  5.00%
# this epoch [..................................................]  0.00%
#        600 iter, 1 epoch / 20 epochs
#     190.23 iters/sec. Estimated time to finish: 0:00:59.926255.
#      total [##................................................]  5.83%
# this epoch [########..........................................] 16.67%
#        700 iter, 1 epoch / 20 epochs
#     198.91 iters/sec. Estimated time to finish: 0:00:56.809133.
#      total [###...............................................]  6.67%
# this epoch [################..................................] 33.33%
#        800 iter, 1 epoch / 20 epochs
#     205.56 iters/sec. Estimated time to finish: 0:00:54.485180.
#      total [###...............................................]  7.50%
# this epoch [#########################.........................] 50.00%
#        900 iter, 1 epoch / 20 epochs
#     210.85 iters/sec. Estimated time to finish: 0:00:52.643856.
#      total [####..............................................]  8.33%
# this epoch [#################################.................] 66.67%
#       1000 iter, 1 epoch / 20 epochs
#     215.15 iters/sec. Estimated time to finish: 0:00:51.126591.
#      total [####..............................................]  9.17%
# this epoch [#########################################.........] 83.33%
#       1100 iter, 1 epoch / 20 epochs
#     218.82 iters/sec. Estimated time to finish: 0:00:49.812622.
# 2           0.0734198   0.0745546             0.977066       0.9771                    13.3269
#      total [#####.............................................] 10.00%
# this epoch [..................................................]  0.00%
#       1200 iter, 2 epoch / 20 epochs
#     201.15 iters/sec. Estimated time to finish: 0:00:53.692065.
#      total [#####.............................................] 10.83%
# this epoch [########..........................................] 16.67%
#       1300 iter, 2 epoch / 20 epochs
#     204.76 iters/sec. Estimated time to finish: 0:00:52.255061.
#      total [#####.............................................] 11.67%
# this epoch [################..................................] 33.33%
#       1400 iter, 2 epoch / 20 epochs
#     207.98 iters/sec. Estimated time to finish: 0:00:50.966418.
#      total [######............................................] 12.50%
# this epoch [#########################.........................] 50.00%
#       1500 iter, 2 epoch / 20 epochs
#     210.89 iters/sec. Estimated time to finish: 0:00:49.790155.
#      total [######............................................] 13.33%
# this epoch [#################################.................] 66.67%
#       1600 iter, 2 epoch / 20 epochs
#     213.44 iters/sec. Estimated time to finish: 0:00:48.724672.
#      total [#######...........................................] 14.17%
# this epoch [#########################################.........] 83.33%
#       1700 iter, 2 epoch / 20 epochs
#     215.72 iters/sec. Estimated time to finish: 0:00:47.747429.
# 3           0.0478672   0.0818652             0.984449       0.9759                    16.1765
#      total [#######...........................................] 15.00%
# this epoch [..................................................]  0.00%
#       1800 iter, 3 epoch / 20 epochs
#     204.91 iters/sec. Estimated time to finish: 0:00:49.777579.
#      total [#######...........................................] 15.83%
# this epoch [########..........................................] 16.67%
#       1900 iter, 3 epoch / 20 epochs
#     207.08 iters/sec. Estimated time to finish: 0:00:48.772444.
#      total [########..........................................] 16.67%
# this epoch [################..................................] 33.33%
#       2000 iter, 3 epoch / 20 epochs
#     209.11 iters/sec. Estimated time to finish: 0:00:47.821350.
#      total [########..........................................] 17.50%
# this epoch [#########################.........................] 50.00%
#       2100 iter, 3 epoch / 20 epochs
#     210.88 iters/sec. Estimated time to finish: 0:00:46.945675.
#      total [#########.........................................] 18.33%
# this epoch [#################################.................] 66.67%
#       2200 iter, 3 epoch / 20 epochs
#     212.56 iters/sec. Estimated time to finish: 0:00:46.103796.
#      total [#########.........................................] 19.17%
# this epoch [#########################################.........] 83.33%
#       2300 iter, 3 epoch / 20 epochs
#     214.14 iters/sec. Estimated time to finish: 0:00:45.296719.
# 4           0.0348934   0.0665179             0.988665       0.9824                    19.0415
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       2400 iter, 4 epoch / 20 epochs
#     206.14 iters/sec. Estimated time to finish: 0:00:46.571004.
#      total [##########........................................] 20.83%
# this epoch [########..........................................] 16.67%
#       2500 iter, 4 epoch / 20 epochs
#     207.78 iters/sec. Estimated time to finish: 0:00:45.721064.
#      total [##########........................................] 21.67%
# this epoch [################..................................] 33.33%
#       2600 iter, 4 epoch / 20 epochs
#     209.35 iters/sec. Estimated time to finish: 0:00:44.900564.
#      total [###########.......................................] 22.50%
# this epoch [#########################.........................] 50.00%
#       2700 iter, 4 epoch / 20 epochs
#     210.79 iters/sec. Estimated time to finish: 0:00:44.119783.
#      total [###########.......................................] 23.33%
# this epoch [#################################.................] 66.67%
#       2800 iter, 4 epoch / 20 epochs
#      212.2 iters/sec. Estimated time to finish: 0:00:43.355545.
#      total [############......................................] 24.17%
# this epoch [#########################################.........] 83.33%
#       2900 iter, 4 epoch / 20 epochs
#     213.53 iters/sec. Estimated time to finish: 0:00:42.616480.
# 5           0.0275089   0.0823065             0.991081       0.978                     21.873
#      total [############......................................] 25.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 5 epoch / 20 epochs
#     207.18 iters/sec. Estimated time to finish: 0:00:43.441396.
#      total [############......................................] 25.83%
# this epoch [########..........................................] 16.67%
#       3100 iter, 5 epoch / 20 epochs
#     208.45 iters/sec. Estimated time to finish: 0:00:42.695757.
#      total [#############.....................................] 26.67%
# this epoch [################..................................] 33.33%
#       3200 iter, 5 epoch / 20 epochs
#     209.75 iters/sec. Estimated time to finish: 0:00:41.954871.
#      total [#############.....................................] 27.50%
# this epoch [#########################.........................] 50.00%
#       3300 iter, 5 epoch / 20 epochs
#     210.97 iters/sec. Estimated time to finish: 0:00:41.238743.
#      total [##############....................................] 28.33%
# this epoch [#################################.................] 66.67%
#       3400 iter, 5 epoch / 20 epochs
#     212.12 iters/sec. Estimated time to finish: 0:00:40.542322.
#      total [##############....................................] 29.17%
# this epoch [#########################################.........] 83.33%
#       3500 iter, 5 epoch / 20 epochs
#     213.21 iters/sec. Estimated time to finish: 0:00:39.867109.
# 6           0.023185    0.0829944             0.992081       0.9782                    24.7061
#      total [###############...................................] 30.00%
# this epoch [..................................................]  0.00%
#       3600 iter, 6 epoch / 20 epochs
#     208.18 iters/sec. Estimated time to finish: 0:00:40.348874.
#      total [###############...................................] 30.83%
# this epoch [########..........................................] 16.67%
#       3700 iter, 6 epoch / 20 epochs
#     209.22 iters/sec. Estimated time to finish: 0:00:39.670970.
#      total [###############...................................] 31.67%
# this epoch [################..................................] 33.33%
#       3800 iter, 6 epoch / 20 epochs
#     210.27 iters/sec. Estimated time to finish: 0:00:38.996851.
#      total [################..................................] 32.50%
# this epoch [#########################.........................] 50.00%
#       3900 iter, 6 epoch / 20 epochs
#     211.28 iters/sec. Estimated time to finish: 0:00:38.337863.
#      total [################..................................] 33.33%
# this epoch [#################################.................] 66.67%
#       4000 iter, 6 epoch / 20 epochs
#     212.24 iters/sec. Estimated time to finish: 0:00:37.692722.
#      total [#################.................................] 34.17%
# this epoch [#########################################.........] 83.33%
#       4100 iter, 6 epoch / 20 epochs
#     213.15 iters/sec. Estimated time to finish: 0:00:37.063256.
# 7           0.0229741   0.0839756             0.992849       0.9792                    27.5325
#      total [#################.................................] 35.00%
# this epoch [..................................................]  0.00%
#       4200 iter, 7 epoch / 20 epochs
#     208.21 iters/sec. Estimated time to finish: 0:00:37.462266.
#      total [#################.................................] 35.83%
# this epoch [########..........................................] 16.67%
#       4300 iter, 7 epoch / 20 epochs
#     209.11 iters/sec. Estimated time to finish: 0:00:36.822627.
#      total [##################................................] 36.67%
# this epoch [################..................................] 33.33%
#       4400 iter, 7 epoch / 20 epochs
#     210.01 iters/sec. Estimated time to finish: 0:00:36.189038.
#      total [##################................................] 37.50%
# this epoch [#########################.........................] 50.00%
#       4500 iter, 7 epoch / 20 epochs
#     210.86 iters/sec. Estimated time to finish: 0:00:35.567904.
#      total [###################...............................] 38.33%
# this epoch [#################################.................] 66.67%
#       4600 iter, 7 epoch / 20 epochs
#     211.68 iters/sec. Estimated time to finish: 0:00:34.959136.
#      total [###################...............................] 39.17%
# this epoch [#########################################.........] 83.33%
#       4700 iter, 7 epoch / 20 epochs
#     212.49 iters/sec. Estimated time to finish: 0:00:34.354173.
# 8           0.018863    0.0883191             0.993749       0.979                     30.4101
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       4800 iter, 8 epoch / 20 epochs
#     208.64 iters/sec. Estimated time to finish: 0:00:34.509825.
#      total [####################..............................] 40.83%
# this epoch [########..........................................] 16.67%
#       4900 iter, 8 epoch / 20 epochs
#     209.39 iters/sec. Estimated time to finish: 0:00:33.908603.
#      total [####################..............................] 41.67%
# this epoch [################..................................] 33.33%
#       5000 iter, 8 epoch / 20 epochs
#     210.18 iters/sec. Estimated time to finish: 0:00:33.304350.
#      total [#####################.............................] 42.50%
# this epoch [#########################.........................] 50.00%
#       5100 iter, 8 epoch / 20 epochs
#     210.92 iters/sec. Estimated time to finish: 0:00:32.713347.
#      total [#####################.............................] 43.33%
# this epoch [#################################.................] 66.67%
#       5200 iter, 8 epoch / 20 epochs
#     211.66 iters/sec. Estimated time to finish: 0:00:32.127444.
#      total [######################............................] 44.17%
# this epoch [#########################################.........] 83.33%
#       5300 iter, 8 epoch / 20 epochs
#     212.36 iters/sec. Estimated time to finish: 0:00:31.549914.
# 9           0.0164346   0.0886821             0.994282       0.9802                    33.2483
#      total [######################............................] 45.00%
# this epoch [..................................................]  0.00%
#       5400 iter, 9 epoch / 20 epochs
#     208.92 iters/sec. Estimated time to finish: 0:00:31.590593.
#      total [######################............................] 45.83%
# this epoch [########..........................................] 16.67%
#       5500 iter, 9 epoch / 20 epochs
#      209.6 iters/sec. Estimated time to finish: 0:00:31.011469.
#      total [#######################...........................] 46.67%
# this epoch [################..................................] 33.33%
#       5600 iter, 9 epoch / 20 epochs
#      210.3 iters/sec. Estimated time to finish: 0:00:30.432736.
#      total [#######################...........................] 47.50%
# this epoch [#########################.........................] 50.00%
#       5700 iter, 9 epoch / 20 epochs
#     210.99 iters/sec. Estimated time to finish: 0:00:29.859843.
#      total [########################..........................] 48.33%
# this epoch [#################################.................] 66.67%
#       5800 iter, 9 epoch / 20 epochs
#     211.63 iters/sec. Estimated time to finish: 0:00:29.296927.
#      total [########################..........................] 49.17%
# this epoch [#########################################.........] 83.33%
#       5900 iter, 9 epoch / 20 epochs
#     212.27 iters/sec. Estimated time to finish: 0:00:28.737007.
# 10          0.0117338   0.0872763             0.996166       0.9813                    36.0872
#      total [#########################.........................] 50.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 10 epoch / 20 epochs
#     209.31 iters/sec. Estimated time to finish: 0:00:28.665702.
#      total [#########################.........................] 50.83%
# this epoch [########..........................................] 16.67%
#       6100 iter, 10 epoch / 20 epochs
#     209.93 iters/sec. Estimated time to finish: 0:00:28.104685.
#      total [#########################.........................] 51.67%
# this epoch [################..................................] 33.33%
#       6200 iter, 10 epoch / 20 epochs
#     210.57 iters/sec. Estimated time to finish: 0:00:27.544410.
#      total [##########################........................] 52.50%
# this epoch [#########################.........................] 50.00%
#       6300 iter, 10 epoch / 20 epochs
#     211.14 iters/sec. Estimated time to finish: 0:00:26.995933.
#      total [##########################........................] 53.33%
# this epoch [#################################.................] 66.67%
#       6400 iter, 10 epoch / 20 epochs
#     211.73 iters/sec. Estimated time to finish: 0:00:26.449023.
#      total [###########################.......................] 54.17%
# this epoch [#########################################.........] 83.33%
#       6500 iter, 10 epoch / 20 epochs
#      212.3 iters/sec. Estimated time to finish: 0:00:25.906181.
# 11          0.0148841   0.0848824             0.995548       0.9799                    38.9076
#      total [###########################.......................] 55.00%
# this epoch [..................................................]  0.00%
#       6600 iter, 11 epoch / 20 epochs
#     209.59 iters/sec. Estimated time to finish: 0:00:25.764324.
#      total [###########################.......................] 55.83%
# this epoch [########..........................................] 16.67%
#       6700 iter, 11 epoch / 20 epochs
#     210.15 iters/sec. Estimated time to finish: 0:00:25.219708.
#      total [############################......................] 56.67%
# this epoch [################..................................] 33.33%
#       6800 iter, 11 epoch / 20 epochs
#     210.71 iters/sec. Estimated time to finish: 0:00:24.678959.
#      total [############################......................] 57.50%
# this epoch [#########################.........................] 50.00%
#       6900 iter, 11 epoch / 20 epochs
#     211.25 iters/sec. Estimated time to finish: 0:00:24.141601.
#      total [#############################.....................] 58.33%
# this epoch [#################################.................] 66.67%
#       7000 iter, 11 epoch / 20 epochs
#      211.8 iters/sec. Estimated time to finish: 0:00:23.607240.
#      total [#############################.....................] 59.17%
# this epoch [#########################################.........] 83.33%
#       7100 iter, 11 epoch / 20 epochs
#     212.33 iters/sec. Estimated time to finish: 0:00:23.077791.
# 12          0.0158016   0.104269              0.994949       0.9795                    41.7327
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       7200 iter, 12 epoch / 20 epochs
#     209.81 iters/sec. Estimated time to finish: 0:00:22.877717.
#      total [##############################....................] 60.83%
# this epoch [########..........................................] 16.67%
#       7300 iter, 12 epoch / 20 epochs
#     210.33 iters/sec. Estimated time to finish: 0:00:22.345412.
#      total [##############################....................] 61.67%
# this epoch [################..................................] 33.33%
#       7400 iter, 12 epoch / 20 epochs
#     210.87 iters/sec. Estimated time to finish: 0:00:21.814801.
#      total [###############################...................] 62.50%
# this epoch [#########################.........................] 50.00%
#       7500 iter, 12 epoch / 20 epochs
#      211.4 iters/sec. Estimated time to finish: 0:00:21.286738.
#      total [###############################...................] 63.33%
# this epoch [#################################.................] 66.67%
#       7600 iter, 12 epoch / 20 epochs
#      211.9 iters/sec. Estimated time to finish: 0:00:20.764473.
#      total [################################..................] 64.17%
# this epoch [#########################################.........] 83.33%
#       7700 iter, 12 epoch / 20 epochs
#      212.4 iters/sec. Estimated time to finish: 0:00:20.245097.
# 13          0.00990256  0.100563              0.996966       0.9797                    44.5402
#      total [################################..................] 65.00%
# this epoch [..................................................]  0.00%
#       7800 iter, 13 epoch / 20 epochs
#     210.11 iters/sec. Estimated time to finish: 0:00:19.989136.
#      total [################################..................] 65.83%
# this epoch [########..........................................] 16.67%
#       7900 iter, 13 epoch / 20 epochs
#     210.59 iters/sec. Estimated time to finish: 0:00:19.468767.
#      total [#################################.................] 66.67%
# this epoch [################..................................] 33.33%
#       8000 iter, 13 epoch / 20 epochs
#     211.08 iters/sec. Estimated time to finish: 0:00:18.950085.
#      total [#################################.................] 67.50%
# this epoch [#########################.........................] 50.00%
#       8100 iter, 13 epoch / 20 epochs
#     211.57 iters/sec. Estimated time to finish: 0:00:18.433748.
#      total [##################################................] 68.33%
# this epoch [#################################.................] 66.67%
#       8200 iter, 13 epoch / 20 epochs
#     212.04 iters/sec. Estimated time to finish: 0:00:17.920962.
#      total [##################################................] 69.17%
# this epoch [#########################################.........] 83.33%
#       8300 iter, 13 epoch / 20 epochs
#      212.5 iters/sec. Estimated time to finish: 0:00:17.411630.
# 14          0.0130484   0.0857276             0.996382       0.984                     47.35
#      total [###################################...............] 70.00%
# this epoch [..................................................]  0.00%
#       8400 iter, 14 epoch / 20 epochs
#        210 iters/sec. Estimated time to finish: 0:00:17.143215.
#      total [###################################...............] 70.83%
# this epoch [########..........................................] 16.67%
#       8500 iter, 14 epoch / 20 epochs
#     210.45 iters/sec. Estimated time to finish: 0:00:16.630925.
#      total [###################################...............] 71.67%
# this epoch [################..................................] 33.33%
#       8600 iter, 14 epoch / 20 epochs
#     210.91 iters/sec. Estimated time to finish: 0:00:16.120254.
#      total [####################################..............] 72.50%
# this epoch [#########################.........................] 50.00%
#       8700 iter, 14 epoch / 20 epochs
#     211.37 iters/sec. Estimated time to finish: 0:00:15.612625.
#      total [####################################..............] 73.33%
# this epoch [#################################.................] 66.67%
#       8800 iter, 14 epoch / 20 epochs
#     211.81 iters/sec. Estimated time to finish: 0:00:15.107970.
#      total [#####################################.............] 74.17%
# this epoch [#########################################.........] 83.33%
#       8900 iter, 14 epoch / 20 epochs
#     212.25 iters/sec. Estimated time to finish: 0:00:14.605517.
# 15          0.0100481   0.117661              0.996932       0.9798                    50.2187
#      total [#####################################.............] 75.00%
# this epoch [..................................................]  0.00%
#       9000 iter, 15 epoch / 20 epochs
#     210.24 iters/sec. Estimated time to finish: 0:00:14.269542.
#      total [#####################################.............] 75.83%
# this epoch [########..........................................] 16.67%
#       9100 iter, 15 epoch / 20 epochs
#     210.66 iters/sec. Estimated time to finish: 0:00:13.766240.
#      total [######################################............] 76.67%
# this epoch [################..................................] 33.33%
#       9200 iter, 15 epoch / 20 epochs
#     211.09 iters/sec. Estimated time to finish: 0:00:13.264583.
#      total [######################################............] 77.50%
# this epoch [#########################.........................] 50.00%
#       9300 iter, 15 epoch / 20 epochs
#     211.49 iters/sec. Estimated time to finish: 0:00:12.766766.
#      total [#######################################...........] 78.33%
# this epoch [#################################.................] 66.67%
#       9400 iter, 15 epoch / 20 epochs
#     211.89 iters/sec. Estimated time to finish: 0:00:12.270398.
#      total [#######################################...........] 79.17%
# this epoch [#########################################.........] 83.33%
#       9500 iter, 15 epoch / 20 epochs
#     212.29 iters/sec. Estimated time to finish: 0:00:11.776456.
# 16          0.0110841   0.10763               0.996849       0.9823                    53.0476
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#       9600 iter, 16 epoch / 20 epochs
#     210.31 iters/sec. Estimated time to finish: 0:00:11.411529.
#      total [########################################..........] 80.83%
# this epoch [########..........................................] 16.67%
#       9700 iter, 16 epoch / 20 epochs
#     210.71 iters/sec. Estimated time to finish: 0:00:10.915361.
#      total [########################################..........] 81.67%
# this epoch [################..................................] 33.33%
#       9800 iter, 16 epoch / 20 epochs
#      211.1 iters/sec. Estimated time to finish: 0:00:10.421530.
#      total [#########################################.........] 82.50%
# this epoch [#########################.........................] 50.00%
#       9900 iter, 16 epoch / 20 epochs
#      211.5 iters/sec. Estimated time to finish: 0:00:09.929098.
#      total [#########################################.........] 83.33%
# this epoch [#################################.................] 66.67%
#      10000 iter, 16 epoch / 20 epochs
#     211.89 iters/sec. Estimated time to finish: 0:00:09.438757.
#      total [##########################################........] 84.17%
# this epoch [#########################################.........] 83.33%
#      10100 iter, 16 epoch / 20 epochs
#     212.28 iters/sec. Estimated time to finish: 0:00:08.950437.
# 17          0.0086444   0.100289              0.997333       0.9824                    55.8674
#      total [##########################################........] 85.00%
# this epoch [..................................................]  0.00%
#      10200 iter, 17 epoch / 20 epochs
#     210.06 iters/sec. Estimated time to finish: 0:00:08.568908.
#      total [##########################################........] 85.83%
# this epoch [########..........................................] 16.67%
#      10300 iter, 17 epoch / 20 epochs
#     210.05 iters/sec. Estimated time to finish: 0:00:08.093230.
#      total [###########################################.......] 86.67%
# this epoch [################..................................] 33.33%
#      10400 iter, 17 epoch / 20 epochs
#     210.04 iters/sec. Estimated time to finish: 0:00:07.617441.
#      total [###########################################.......] 87.50%
# this epoch [#########################.........................] 50.00%
#      10500 iter, 17 epoch / 20 epochs
#     210.03 iters/sec. Estimated time to finish: 0:00:07.141864.
#      total [############################################......] 88.33%
# this epoch [#################################.................] 66.67%
#      10600 iter, 17 epoch / 20 epochs
#     213.14 iters/sec. Estimated time to finish: 0:00:06.568368.
#      total [############################################......] 89.17%
# this epoch [#########################################.........] 83.33%
#      10700 iter, 17 epoch / 20 epochs
#     213.14 iters/sec. Estimated time to finish: 0:00:06.099139.
# 18          0.00980269  0.0963337             0.997249       0.9811                    58.6918
#      total [#############################################.....] 90.00%
# this epoch [..................................................]  0.00%
#      10800 iter, 18 epoch / 20 epochs
#     210.91 iters/sec. Estimated time to finish: 0:00:05.689545.
#      total [#############################################.....] 90.83%
# this epoch [########..........................................] 16.67%
#      10900 iter, 18 epoch / 20 epochs
#     210.91 iters/sec. Estimated time to finish: 0:00:05.215546.
#      total [#############################################.....] 91.67%
# this epoch [################..................................] 33.33%
#      11000 iter, 18 epoch / 20 epochs
#     210.91 iters/sec. Estimated time to finish: 0:00:04.741326.
#      total [##############################################....] 92.50%
# this epoch [#########################.........................] 50.00%
#      11100 iter, 18 epoch / 20 epochs
#     210.91 iters/sec. Estimated time to finish: 0:00:04.267133.
#      total [##############################################....] 93.33%
# this epoch [#################################.................] 66.67%
#      11200 iter, 18 epoch / 20 epochs
#     213.21 iters/sec. Estimated time to finish: 0:00:03.752187.
#      total [###############################################...] 94.17%
# this epoch [#########################################.........] 83.33%
#      11300 iter, 18 epoch / 20 epochs
#     213.22 iters/sec. Estimated time to finish: 0:00:03.282980.
# 19          0.0080734   0.123992              0.997499       0.9793                    61.5186
#      total [###############################################...] 95.00%
# this epoch [..................................................]  0.00%
#      11400 iter, 19 epoch / 20 epochs
#     211.02 iters/sec. Estimated time to finish: 0:00:02.843366.
#      total [###############################################...] 95.83%
# this epoch [########..........................................] 16.67%
#      11500 iter, 19 epoch / 20 epochs
#     210.99 iters/sec. Estimated time to finish: 0:00:02.369794.
#      total [################################################..] 96.67%
# this epoch [################..................................] 33.33%
#      11600 iter, 19 epoch / 20 epochs
#     210.98 iters/sec. Estimated time to finish: 0:00:01.895954.
#      total [################################################..] 97.50%
# this epoch [#########################.........................] 50.00%
#      11700 iter, 19 epoch / 20 epochs
#     210.96 iters/sec. Estimated time to finish: 0:00:01.422037.
#      total [#################################################.] 98.33%
# this epoch [#################################.................] 66.67%
#      11800 iter, 19 epoch / 20 epochs
#     213.16 iters/sec. Estimated time to finish: 0:00:00.938279.
#      total [#################################################.] 99.17%
# this epoch [#########################################.........] 83.33%
#      11900 iter, 19 epoch / 20 epochs
#     213.18 iters/sec. Estimated time to finish: 0:00:00.469089.
# 20          0.0109972   0.119942              0.996932       0.9812                    64.3643
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#      12000 iter, 20 epoch / 20 epochs
#     210.85 iters/sec. Estimated time to finish: 0:00:00.
